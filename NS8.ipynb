# %%
import tensorflow as tf
from keras import Sequential,layers,preprocessing
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from keras.preprocessing.sequence import pad_sequences
from keras.src.legacy.preprocessing.text import Tokenizer
import pandas as pd

# %%
data=pd.read_csv('sentiment_data.csv')

# %%
texts=data['Comment'].values
texts
# Out:
# array(['lets forget apple pay required brand new iphone order use significant portion apples user base wasnt able use even wanted successive iphone incorporated technology older iphones replaced number people could use technology increased',
#        'nz retailers don’t even contactless credit card machines like paywave support apple pay don’t like high fees come',
#        'forever acknowledge channel help lessons ideas explanations quite helpful youll sit comfort monitor account growth',
#        ..., 'cover interaction forum left',
#        'big project came india modi dream project happened reality',
#        'ever listen like gurukul discipline maintained even narendra modi rss maintaining culture indian attack politics someone attack hinduism rss take action proud'],
#       dtype=object)

# %%
labels=data['Sentiment'].values
labels
# Out:
# array([1, 0, 2, ..., 1, 1, 2])

# %%
tokenizer = Tokenizer(num_words=10000)

# %%
tokenizer.fit_on_texts(texts)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 tokenizer.fit_on_texts(texts)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\keras\src\legacy\preprocessing\text.py:133, in Tokenizer.fit_on_texts(self, texts)
#     131 else:
#     132     if self.analyzer is None:
# --> 133         seq = text_to_word_sequence(
#     134             text,
#     135             filters=self.filters,
#     136             lower=self.lower,
#     137             split=self.split,
#     138         )
#     139     else:
#     140         seq = self.analyzer(text)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\keras\src\legacy\preprocessing\text.py:22, in text_to_word_sequence(input_text, filters, lower, split)
#      20 """DEPRECATED."""
#      21 if lower:
# ---> 22     input_text = input_text.lower()
#      24 translate_dict = {c: split for c in filters}
#      25 translate_map = str.maketrans(translate_dict)
#
# AttributeError: 'float' object has no attribute 'lower'

# %%
sequences = tokenizer.texts_to_sequences(texts)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 sequences = tokenizer.texts_to_sequences(texts)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\keras\src\legacy\preprocessing\text.py:177, in Tokenizer.texts_to_sequences(self, texts)
#     176 def texts_to_sequences(self, texts):
# --> 177     return list(self.texts_to_sequences_generator(texts))
#
# File C:\ProgramData\anaconda3\Lib\site-packages\keras\src\legacy\preprocessing\text.py:192, in Tokenizer.texts_to_sequences_generator(self, texts)
#     190 else:
#     191     if self.analyzer is None:
# --> 192         seq = text_to_word_sequence(
#     193             text,
#     194             filters=self.filters,
#     195             lower=self.lower,
#     196             split=self.split,
#     197         )
#     198     else:
#     199         seq = self.analyzer(text)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\keras\src\legacy\preprocessing\text.py:22, in text_to_word_sequence(input_text, filters, lower, split)
#      20 """DEPRECATED."""
#      21 if lower:
# ---> 22     input_text = input_text.lower()
#      24 translate_dict = {c: split for c in filters}
#      25 translate_map = str.maketrans(translate_dict)
#
# AttributeError: 'float' object has no attribute 'lower'
